# %%
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
df = pd.read_csv("Most Streamed Spotify Songs 2024.csv", encoding='latin1')

# %%
df.head()
# Out:
#                         Track                    Album Name          Artist  \
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single   Tommy Richman
# 1                 Not Like Us                   Not Like Us  Kendrick Lamar
# 2  i like the way you kiss me    I like the way you kiss me         Artemas
# 3                     Flowers              Flowers - Single     Miley Cyrus
# 4                     Houdini                       Houdini          Eminem
#
#   Release Date          ISRC All Time Rank  Track Score Spotify Streams  \
# 0    4/26/2024  QM24S2402528             1        725.4     390,470,936
# 1     5/4/2024  USUG12400910             2        545.9     323,703,884
# 2    3/19/2024  QZJ842400387             3        538.4     601,309,283
# 3    1/12/2023  USSM12209777             4        444.9   2,031,280,633
# 4    5/31/2024  USUG12403398             5        423.3     107,034,922
#
#   Spotify Playlist Count Spotify Playlist Reach  ...  SiriusXM Spins  \
# ...

# %%
# Standardize column names: lowercase and replace spaces with underscores
df.columns = df.columns.str.lower().str.replace(' ', '_').str.strip()

# Print the updated column names
print(df.columns)
# Out:
# Index(['track', 'album_name', 'artist', 'release_date', 'isrc',
#        'all_time_rank', 'track_score', 'spotify_streams',
#        'spotify_playlist_count', 'spotify_playlist_reach',
#        'spotify_popularity', 'youtube_views', 'youtube_likes', 'tiktok_posts',
#        'tiktok_likes', 'tiktok_views', 'youtube_playlist_reach',
#        'apple_music_playlist_count', 'airplay_spins', 'siriusxm_spins',
#        'deezer_playlist_count', 'deezer_playlist_reach',
#        'amazon_playlist_count', 'pandora_streams', 'pandora_track_stations',
#        'soundcloud_streams', 'shazam_counts', 'tidal_popularity',
#        'explicit_track'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   track                       4600 non-null   object
#  1   album_name                  4600 non-null   object
#  2   artist                      4595 non-null   object
#  3   release_date                4600 non-null   object
#  4   isrc                        4600 non-null   object
#  5   all_time_rank               4600 non-null   object
#  6   track_score                 4600 non-null   float64
#  7   spotify_streams             4487 non-null   object
#  8   spotify_playlist_count      4530 non-null   object
#  9   spotify_playlist_reach      4528 non-null   object
#  10  spotify_popularity          3796 non-null   float64
#  11  youtube_views               4292 non-null   object
#  12  youtube_likes               4285 non-null   object
# ...

# %%
df.describe()
# Out:
#        track_score  spotify_popularity  apple_music_playlist_count  \
# count  4600.000000         3796.000000                  4039.00000
# mean     41.844043           63.501581                    54.60312
# std      38.543766           16.186438                    71.61227
# min      19.400000            1.000000                     1.00000
# 25%      23.300000           61.000000                    10.00000
# 50%      29.900000           67.000000                    28.00000
# 75%      44.425000           73.000000                    70.00000
# max     725.400000           96.000000                   859.00000
#
#        deezer_playlist_count  amazon_playlist_count  tidal_popularity  \
# count            3679.000000            3545.000000               0.0
# mean               32.310954              25.348942               NaN
# std                54.274538              25.989826               NaN
# min                 1.000000               1.000000               NaN
# ...

# %%
df.isnull().sum()
# Out:
# track                            0
# album_name                       0
# artist                           5
# release_date                     0
# isrc                             0
# all_time_rank                    0
# track_score                      0
# spotify_streams                113
# spotify_playlist_count          70
# spotify_playlist_reach          72
# spotify_popularity             804
# youtube_views                  308
# youtube_likes                  315
# tiktok_posts                  1173
# tiktok_likes                   980
# tiktok_views                   981
# youtube_playlist_reach        1009
# apple_music_playlist_count     561
# airplay_spins                  498
# siriusxm_spins                2123
# deezer_playlist_count          921
# deezer_playlist_reach          928
# amazon_playlist_count         1055
# pandora_streams               1106
# pandora_track_stations        1268
# soundcloud_streams            3333
# shazam_counts                  577
# ...

# %%
#changing Dtype
df['all_time_rank'] = df['all_time_rank'].str.replace(',', '').astype('int64')
df['spotify_streams'] = df['spotify_streams'].astype(str).str.replace(',', '').astype('float64')

# %%
# List of columns to convert
columns_to_convert = [
    'spotify_playlist_count', 'spotify_playlist_reach', 'youtube_views', 'youtube_likes', 
    'tiktok_posts', 'tiktok_likes', 'tiktok_views', 'youtube_playlist_reach'
]

# Loop through each column and convert
for column in columns_to_convert:
    df[column] = pd.to_numeric(df[column].astype(str).str.replace(',', ''), errors='coerce')

# Check the results
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   track                       4600 non-null   object
#  1   album_name                  4600 non-null   object
#  2   artist                      4595 non-null   object
#  3   release_date                4600 non-null   object
#  4   isrc                        4600 non-null   object
#  5   all_time_rank               4600 non-null   int64
#  6   track_score                 4600 non-null   float64
#  7   spotify_streams             4487 non-null   float64
#  8   spotify_playlist_count      4530 non-null   float64
#  9   spotify_playlist_reach      4528 non-null   float64
#  10  spotify_popularity          3796 non-null   float64
#  11  youtube_views               4292 non-null   float64
#  12  youtube_likes               4285 non-null   float64
# ...

# %%
#new and updated statical description
df.describe()
# Out:
#        all_time_rank  track_score  spotify_streams  spotify_playlist_count  \
# count    4600.000000  4600.000000     4.487000e+03             4530.000000
# mean     2290.678043    41.844043     4.473873e+08            59390.829801
# std      1322.878312    38.543766     5.384439e+08            71131.406625
# min         1.000000    19.400000     1.071000e+03                1.000000
# 25%      1144.750000    23.300000     7.038630e+07             6718.000000
# 50%      2290.500000    29.900000     2.398507e+08            32312.500000
# 75%      3436.250000    44.425000     6.283638e+08            86038.750000
# max      4998.000000   725.400000     4.281469e+09           590392.000000
#
#        spotify_playlist_reach  spotify_popularity  youtube_views  \
# count            4.528000e+03         3796.000000   4.292000e+03
# mean             2.334682e+07           63.501581   4.027967e+08
# std              2.968717e+07           16.186438   7.019000e+08
# ...

# %%
df.isnull().sum()
# Out:
# track                            0
# album_name                       0
# artist                           5
# release_date                     0
# isrc                             0
# all_time_rank                    0
# track_score                      0
# spotify_streams                113
# spotify_playlist_count          70
# spotify_playlist_reach          72
# spotify_popularity             804
# youtube_views                  308
# youtube_likes                  315
# tiktok_posts                  1173
# tiktok_likes                   980
# tiktok_views                   981
# youtube_playlist_reach        1009
# apple_music_playlist_count     561
# airplay_spins                  498
# siriusxm_spins                2123
# deezer_playlist_count          921
# deezer_playlist_reach          928
# amazon_playlist_count         1055
# pandora_streams               1106
# pandora_track_stations        1268
# soundcloud_streams            3333
# shazam_counts                  577
# ...

# %% [markdown]
# Handling missing data

# %%
df[df['artist'].isnull()]
# Out:
#                               track                              album_name  \
# 311                            Cool                                 JnD Mix
# 480                   I Wanna Party                  I Wanna Party - Single
# 1345                 Marlboro Remix                 Marlboro Remix - Single
# 1561                        Melting                        Melting - Single
# 3402  La ï¿½ï¿½ltima Vez (Yo Te Per  La ï¿½ï¿½ltima Vez (Yo Te Perdï¿½ï¿½)
#
#      artist release_date          isrc  all_time_rank  track_score  \
# 311     NaN    5/25/2024  QZNWQ2410638            311         86.5
# 480     NaN    5/31/2024  QZYFZ2445017            482         70.3
# 1345    NaN     6/7/2024  QZNWT2471497           1343         40.6
# 1561    NaN    6/10/2024  QZNWU2402635           1553         37.2
# 3402    NaN     5/2/2024  MX2832415361           3381         23.6
#
#       spotify_streams  spotify_playlist_count  spotify_playlist_reach  ...  \
# ...

# %%
df['artist'].fillna('Unknown', inplace=True)
# Out:
# C:\Users\welcome\AppData\Local\Temp\ipykernel_12500\1996077361.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['artist'].fillna('Unknown', inplace=True)

# %%
mean_value = df['spotify_streams'].mean()
df['spotify_streams'].fillna(mean_value, inplace=True)
# Out:
# C:\Users\welcome\AppData\Local\Temp\ipykernel_12500\881745561.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['spotify_streams'].fillna(mean_value, inplace=True)

# %%
mean_playlist_count = df['spotify_playlist_count'].mean()
df['spotify_playlist_count'].fillna(mean_playlist_count, inplace=True)

mean_playlist_reach = df['spotify_playlist_reach'].mean()
df['spotify_playlist_reach'].fillna(mean_playlist_reach, inplace=True)
# Out:
# C:\Users\welcome\AppData\Local\Temp\ipykernel_12500\1877380296.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['spotify_playlist_count'].fillna(mean_playlist_count, inplace=True)
# C:\Users\welcome\AppData\Local\Temp\ipykernel_12500\1877380296.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# Replace missing values with median 
df['spotify_popularity'].fillna(df['spotify_popularity'].median(), inplace=True)
df['youtube_views'].fillna(df['youtube_views'].median(), inplace=True)
df['youtube_likes'].fillna(df['youtube_likes'].median(), inplace=True)
df['tiktok_posts'].fillna(df['tiktok_posts'].median(), inplace=True)
df['tiktok_likes'].fillna(df['tiktok_likes'].median(), inplace=True)
df['tiktok_views'].fillna(df['tiktok_views'].median(), inplace=True)
df['youtube_playlist_reach'].fillna(df['youtube_playlist_reach'].median(), inplace=True)
df['apple_music_playlist_count'].fillna(df['apple_music_playlist_count'].median(), inplace=True)
# Out:
# C:\Users\welcome\AppData\Local\Temp\ipykernel_12500\3737121805.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['spotify_popularity'].fillna(df['spotify_popularity'].median(), inplace=True)
# C:\Users\welcome\AppData\Local\Temp\ipykernel_12500\3737121805.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.isnull().sum()
# Out:
# track                            0
# album_name                       0
# artist                           0
# release_date                     0
# isrc                             0
# all_time_rank                    0
# track_score                      0
# spotify_streams                  0
# spotify_playlist_count           0
# spotify_playlist_reach           0
# spotify_popularity               0
# youtube_views                    0
# youtube_likes                    0
# tiktok_posts                     0
# tiktok_likes                     0
# tiktok_views                     0
# youtube_playlist_reach           0
# apple_music_playlist_count       0
# airplay_spins                  498
# siriusxm_spins                2123
# deezer_playlist_count          921
# deezer_playlist_reach          928
# amazon_playlist_count         1055
# pandora_streams               1106
# pandora_track_stations        1268
# soundcloud_streams            3333
# shazam_counts                  577
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   track                       4600 non-null   object
#  1   album_name                  4600 non-null   object
#  2   artist                      4600 non-null   object
#  3   release_date                4600 non-null   object
#  4   isrc                        4600 non-null   object
#  5   all_time_rank               4600 non-null   int64
#  6   track_score                 4600 non-null   float64
#  7   spotify_streams             4600 non-null   float64
#  8   spotify_playlist_count      4600 non-null   float64
#  9   spotify_playlist_reach      4600 non-null   float64
#  10  spotify_popularity          4600 non-null   float64
#  11  youtube_views               4600 non-null   float64
#  12  youtube_likes               4600 non-null   float64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select numerical columns for plotting
numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns

# Set up the figure and axis for the plots
plt.figure(figsize=(15, 15))

# Plot histograms for each numerical feature
for i, col in enumerate(numerical_columns):
    plt.subplot(5, 5, i + 1)  # Arrange in a 5x5 grid
    sns.histplot(df[col], kde=True, bins=30, color='skyblue')
    plt.title(f'Distribution of {col}')
    plt.tight_layout()

plt.show()

# %%
# Ensure all columns are float64
df[numerical_columns] = df[numerical_columns].apply(pd.to_numeric, errors='coerce')

# Try plotting one boxplot to debug
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['spotify_streams'], color='lightgreen')
plt.title('Boxplot of Spotify Streams')
plt.show()

# %%
# Calculate the Q1 (25th percentile) and Q3 (75th percentile) for 'spotify_streams'
Q1 = df['spotify_streams'].quantile(0.25)
Q3 = df['spotify_streams'].quantile(0.75)
IQR = Q3 - Q1

# Define the outlier boundaries
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['spotify_streams'] < lower_bound) | (df['spotify_streams'] > upper_bound)]

# Print the outliers
print("Outliers in spotify_streams:\n", outliers)

# Handle outliers (example: remove them or replace with the median)
df['spotify_streams'] = df['spotify_streams'].apply(
    lambda x: df['spotify_streams'].median() if x < lower_bound or x > upper_bound else x
)

# After handling outliers, let's plot the boxplot again to see the effect
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['spotify_streams'], color='lightgreen')
plt.title('Boxplot of Spotify Streams (After Outlier Handling)')
plt.show()
# Out:
# Outliers in spotify_streams:
#                            track  \
# 3                       Flowers
# 8          Danza Kuduro - Cover
# 19                    As It Was
# 22         Danza Kuduro - Cover
# 26    STAY (with Justin Bieber)
# ...                         ...
# 4318              The Scientist
# 4331                  Kill Bill
# 4359            Me Porto Bonito
# 4522    Smells Like Teen Spirit
# 4539  Cake By The Ocean - Cover
#
#                                              album_name           artist  \
# 3                                      Flowers - Single      Miley Cyrus
# 8          ýýýýýýýýýýýýýýýýýýýýý - ýýýýýýýýýýýýýýýýýý -    MUSIC LAB JPN
# 19                                            As It Was     Harry Styles
# 22                      CLUB DE YOKUKIKU YOUGAKU MEDLEY    MUSIC LAB JPN
# 26                            STAY (with Justin Bieber)    The Kid LAROI
# ...                                                 ...              ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   track                       4600 non-null   object
#  1   album_name                  4600 non-null   object
#  2   artist                      4600 non-null   object
#  3   release_date                4600 non-null   object
#  4   isrc                        4600 non-null   object
#  5   all_time_rank               4600 non-null   int64
#  6   track_score                 4600 non-null   float64
#  7   spotify_streams             4600 non-null   float64
#  8   spotify_playlist_count      4600 non-null   float64
#  9   spotify_playlist_reach      4600 non-null   float64
#  10  spotify_popularity          4600 non-null   float64
#  11  youtube_views               4600 non-null   float64
#  12  youtube_likes               4600 non-null   float64
# ...

# %%
# Correlation heatmap
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
# Group by artist and calculate mean streams
artist_stats = df.groupby('artist')['spotify_streams'].mean().sort_values(ascending=False).head(10)
print(artist_stats)
# Out:
# artist
# The Walters           1.410353e+09
# gnash                 1.405772e+09
# Carly Rae Jepsen      1.394048e+09
# DJ Laxman             1.389773e+09
# MKTO                  1.350428e+09
# Axwell /\ Ingrosso    1.346174e+09
# Jessie J              1.336196e+09
# Miguel                1.335928e+09
# Gym Class Heroes      1.318597e+09
# Portugal. The Man     1.303236e+09
# Name: spotify_streams, dtype: float64

# %%
# Explicit vs. Non-Explicit tracks
explicit_stats = df.groupby('explicit_track')['spotify_streams'].mean()
print(explicit_stats)
# Out:
# explicit_track
# 0    3.290918e+08
# 1    3.375151e+08
# Name: spotify_streams, dtype: float64
